# %%
# %pip install pandas -q
# %pip install numpy -q

import numpy as np
import pandas as pd
import random
from collections import Counter
import copy
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Data Preparation

# %%
with open ("Dataset/Hurink_Data/vdata/abz5.fjs","r") as file:
    firstLine = file.readline()
    firstLineValues = [int(i) for i in firstLine.split()[0:2]]
    NUM_JOBS = firstLineValues[0] 
    NUM_MACHINES = firstLineValues[1]
    print(f"numJobs = {NUM_JOBS}, numMachines = {NUM_MACHINES}")
    
    data = []  
    for txts in file.readlines():
        job = []
        operations = txts.split()[1:]
        index = 0
        while index < len(operations):
            operation = []
            numberOfOperation = int(operations[index])
            index += 1
            endOperationIndex = numberOfOperation*2 + index
            while index < endOperationIndex:
                operation.append({"machineNumber": int(operations[index]), "processTime": int(operations[index+1])})
                index += 2
            job.append(operation)
        data.append(job)

dueDate = [{np.int64(4): 1550, np.int64(9): 1500, np.int64(0): 1300, np.int64(2): 1300, np.int64(5): 1250, np.int64(3): 1180, np.int64(1): 1171, np.int64(7): 1141, np.int64(6): 1113, np.int64(8): 1006}]

# data = [job0, job1, .... ]
# job1 = , [op0, op1, op2, ....]
# op1 = [{macineNumber: , processTime: },{machineNumber: , processTime: }...]
print(f"number of first job's operation = {len(data[0])}")
print(f"number of machine that first job's operation can use = {len(data[0][0])}")
# Out:
# numJobs = 10, numMachines = 10
# number of first job's operation = 10
# number of machine that first job's operation can use = 5

# %% [markdown]
# ## Hyper Parameter

# %%
POP_SIZE = 30
CROSSOVER_RATE = 0.7
MAX_ITERATION = 400
NUMBER_OF_ELITISM_SURVIVORS = 2
NUMBER_OF_TOURNAMENT_COMPETITORS = 2

# %% [markdown]
# ## Generate Initial Population

# %%
# Initial population = [[J0, M3], [J0, M4], [J2, M1], [J3, M2], [J0, M1], ...]
# meaning J1 first operation use Machine 3 -> J2 first operation use Machine 4  -> J1 second operation......

def generateInitailPopulation():
    # create all jobs with specific number of operations
    # because different Jobs could have different number of operations
    baseArray = []
    for index in range(len(data)):   
        baseArray.extend(np.tile(index, len(data[index])))
    
    population = []
    # random choose that jobs operation for
    for _ in range(POP_SIZE):
        # how many operations have done
        c = Counter()
        individual = []
        baseArray = np.random.permutation(baseArray)
        for job in baseArray:
            machine = random.choice(data[job][c[job]])
            c[job]+=1
            individual.append([job, machine["machineNumber"]])
        population.append(individual)
    return population

# %% [markdown]
# ## Repairment

# %%
# repairment deal with infieasible solution (the operation can't performed by that machine)
# When happens, it randomly choose a feasilbe machine that can perform that operation
def repair(unrepaired):
    operationCounter = Counter()
    repairedList = copy.deepcopy(unrepaired)
    for i in range(len(unrepaired)):
        jobNum = unrepaired[i][0]
        machineNum = unrepaired[i][1]
        machines = [i["machineNumber"] for i in data[jobNum][operationCounter[jobNum]]]
        if machineNum not in machines:
            repairedList[i][1] = random.choice(machines)
        operationCounter[jobNum]+=1
    return repairedList

# %% [markdown]
# ## Fitness Evaluation

# %%
def evaluateFitnessScore(chromosome):
    
    # Job shows how many times of operation have been done
    # Job_end shows the time that last Ji ends
    # machine time shows the time that last job ends
    jobCounter = Counter()
    jobEndCounter = Counter()
    machineTimeCounter = Counter()
    
    for jobIteration in chromosome:
        jobNumber = jobIteration[0]
        machineNumber = jobIteration[1]
        
        # calculate the duration of that specific operation
        operationsDictList = data[jobNumber][jobCounter[jobNumber]]
        duration = [i["processTime"] for i in operationsDictList if i["machineNumber"] == machineNumber][0]
         
        # update the counter
        machineTimeCounter[machineNumber] = max(machineTimeCounter[machineNumber], jobEndCounter[jobNumber])
        machineTimeCounter[machineNumber] += duration
        jobEndCounter[jobNumber] = machineTimeCounter[machineNumber]
        jobCounter[jobNumber] += 1
        
    # calcualte makespan & tardiness
    makespan = jobEndCounter.most_common(1)[0][1]
    
    return makespan

# %% [markdown]
# ## Selection

# %%
# Tournament method
def selection(populatoinWithMakespan):
    population = populatoinWithMakespan["population"]
    makespan = populatoinWithMakespan["makespan"]
    selected = []
    for _ in range(2):
        competitors = np.random.permutation(len(population))[:NUMBER_OF_TOURNAMENT_COMPETITORS]
        
        v = max(makespan[i] for i in competitors)
        for i in competitors:
            if makespan[i]==v:
                selected.append([population[i], makespan[i]])
                break
        
    return pd.DataFrame(selected,columns=["population", "makespan"])

# %% [markdown]
# ##  Crossover & Mutation

# %%
# Davis’ Order Crossover 
def crossover(individual1, individual2):
    length = len(individual1)

    # Initialize the offspring with None values
    offspring1 = [None] * length
    offspring2 = [None] * length
    
    # Choose two crossover points
    cxpoint1, cxpoint2 = sorted(random.sample(range(length), 2))
    
    # Copy the sub-sequence from parent1 to offspring1 and parent2 to offspring2
    offspring1[cxpoint1:cxpoint2] = individual1[cxpoint1:cxpoint2]
    offspring2[cxpoint1:cxpoint2] = individual2[cxpoint1:cxpoint2]
    
    # Create a counter for each offspring
    counter1 = Counter(i[0] for i in offspring1[cxpoint1:cxpoint2])
    counter2 = Counter(i[0] for i in offspring2[cxpoint1:cxpoint2])
    
    def fill_offspring(parent, offspring, counter):
        current_pos = 0
        for gene in parent:
            jobNum = gene[0]
            machineNum = gene[1]
            if counter[jobNum] < len(data[jobNum]):
                while offspring[current_pos] is not None:
                    current_pos = (current_pos + 1) % length
                offspring[current_pos] = [jobNum, machineNum]  
                counter[jobNum] += 1
    
    # Fill the rest of the genes in the offspring
    fill_offspring(individual2, offspring1, counter1)
    fill_offspring(individual1, offspring2, counter2)
    
    return [repair(offspring1), repair(offspring2)]

# Change side if 
def mutate(individual):
    mutateOffspring = copy.deepcopy(individual)
    i, j = random.sample(range(len(individual)), 2)
    mutateOffspring[i], mutateOffspring[j] = mutateOffspring[j], mutateOffspring[i]
    return repair(mutateOffspring)

# %% [markdown]
# ## Elitism Strategy

# %%
def elitismStrategy(population):
    sorted_df = population.sort_values(by=["makespan"], ascending=[True])
    survivors_df = sorted_df.head(NUMBER_OF_ELITISM_SURVIVORS)
    return survivors_df

# %% [markdown]
# ## Main Function

# %%
iteration = 0
populationList = []
lineGraphDataList = []
elitismIndividualDF = pd.DataFrame()

while(iteration <= MAX_ITERATION):
    if len(populationList) == 0 :
        populationList = generateInitailPopulation()
    else:
        populationList = [i[0] for i in offspringList]
        
    # scored the population
    scoredPopulationList = []
    for chromosome in populationList:
        makespan = evaluateFitnessScore(chromosome)
        scoredPopulationList.append([chromosome, makespan])
    
    # select two individual from the population and crossover & mutation until meet the pop size
    offspringList = []
    scoredPopulationList.extend(elitismIndividualDF.values)
    while len(offspringList) <= POP_SIZE:
        selectedIndividual = selection(pd.DataFrame(scoredPopulationList,columns=["population", "makespan"]))
        if random.random() < CROSSOVER_RATE:
            offsprings = crossover(selectedIndividual.iloc[0,0],selectedIndividual.iloc[1,0])
            for offspring in offsprings:
                makespan = evaluateFitnessScore(offspring)
                offspringList.append([offspring, makespan])
        else:
            offspring = mutate(selectedIndividual.iloc[0,0])
            makespan = evaluateFitnessScore(offspring)
            offspringList.append([offspring, makespan])

    
    # sort by makespan (ascending)
    offspringList.extend(elitismIndividualDF.values)
    elitismIndividualDF = elitismStrategy(pd.DataFrame(offspringList, columns=["population", "makespan"]))
    
    iteration+=1
    lineGraphDataList.append(elitismIndividualDF.iloc[0,1])
    print(f"interation: {iteration}")
    print(f"best makespan: {elitismIndividualDF.iloc[0,1]} \n")
# Out:
# interation: 1
# best makespan: 1833
#
# interation: 2
# best makespan: 1833
#
# interation: 3
# best makespan: 1827
#
# interation: 4
# best makespan: 1827
#
# interation: 5
# best makespan: 1827
#
# interation: 6
# best makespan: 1809
#
# interation: 7
# best makespan: 1809
#
# interation: 8
# best makespan: 1678
#
# interation: 9
# best makespan: 1678
#
# interation: 10
# best makespan: 1678
#
# interation: 11
# best makespan: 1678
#
# interation: 12
# best makespan: 1678
#
# interation: 13
# best makespan: 1678
#
# interation: 14
# best makespan: 1678
#
# interation: 15
# best makespan: 1678
#
# interation: 16
# best makespan: 1678
#
# interation: 17
# best makespan: 1678
#
# interation: 18
# best makespan: 1678
#
# interation: 19
# best makespan: 1678
#
# interation: 20
# best makespan: 1678
#
# interation: 21
# best makespan: 1678
#
# interation: 22
# best makespan: 1678
#
# interation: 23
# best makespan: 1678
#
# interation: 24
# best makespan: 1678
#
# interation: 25
# best makespan: 1678
#
# interation: 26
# best makespan: 1678
#
# interation: 27
# best makespan: 1678
#
# interation: 28
# best makespan: 1678
#
# interation: 29
# best makespan: 1678
#
# interation: 30
# best makespan: 1678
#
# interation: 31
# best makespan: 1678
#
# interation: 32
# best makespan: 1678
#
# interation: 33
# best makespan: 1678
#
# interation: 34
# best makespan: 1678
#
# interation: 35
# best makespan: 1678
#
# interation: 36
# best makespan: 1678
#
# interation: 37
# best makespan: 1678
#
# interation: 38
# best makespan: 1678
#
# interation: 39
# best makespan: 1678
#
# interation: 40
# best makespan: 1678
#
# interation: 41
# best makespan: 1678
#
# interation: 42
# best makespan: 1678
#
# interation: 43
# best makespan: 1678
#
# interation: 44
# best makespan: 1678
#
# interation: 45
# best makespan: 1672
#
# interation: 46
# best makespan: 1672
#
# interation: 47
# best makespan: 1672
#
# interation: 48
# best makespan: 1672
#
# interation: 49
# best makespan: 1672
#
# interation: 50
# best makespan: 1672
#
# interation: 51
# best makespan: 1672
#
# interation: 52
# best makespan: 1672
#
# interation: 53
# best makespan: 1672
#
# interation: 54
# best makespan: 1672
#
# interation: 55
# best makespan: 1672
#
# interation: 56
# best makespan: 1672
#
# interation: 57
# best makespan: 1672
#
# interation: 58
# best makespan: 1672
#
# interation: 59
# best makespan: 1672
#
# interation: 60
# best makespan: 1672
#
# interation: 61
# best makespan: 1672
#
# interation: 62
# best makespan: 1672
#
# interation: 63
# best makespan: 1672
#
# interation: 64
# best makespan: 1672
#
# interation: 65
# best makespan: 1672
#
# interation: 66
# best makespan: 1672
#
# interation: 67
# best makespan: 1672
#
# interation: 68
# best makespan: 1672
#
# interation: 69
# best makespan: 1672
#
# interation: 70
# best makespan: 1672
#
# interation: 71
# best makespan: 1672
#
# interation: 72
# best makespan: 1672
#
# interation: 73
# best makespan: 1672
#
# interation: 74
# best makespan: 1672
#
# interation: 75
# best makespan: 1672
#
# interation: 76
# best makespan: 1672
#
# interation: 77
# best makespan: 1672
#
# interation: 78
# best makespan: 1672
#
# interation: 79
# best makespan: 1672
#
# interation: 80
# best makespan: 1672
#
# interation: 81
# best makespan: 1672
#
# interation: 82
# best makespan: 1672
#
# interation: 83
# best makespan: 1672
#
# interation: 84
# best makespan: 1672
#
# interation: 85
# best makespan: 1665
#
# interation: 86
# best makespan: 1665
#
# interation: 87
# best makespan: 1665
#
# interation: 88
# best makespan: 1665
#
# interation: 89
# best makespan: 1665
#
# interation: 90
# best makespan: 1665
#
# interation: 91
# best makespan: 1665
#
# interation: 92
# best makespan: 1665
#
# interation: 93
# best makespan: 1665
#
# interation: 94
# best makespan: 1665
#
# interation: 95
# best makespan: 1665
#
# interation: 96
# best makespan: 1665
#
# interation: 97
# best makespan: 1665
#
# interation: 98
# best makespan: 1665
#
# interation: 99
# best makespan: 1665
#
# interation: 100
# best makespan: 1665
#
# interation: 101
# best makespan: 1665
#
# interation: 102
# best makespan: 1665
#
# interation: 103
# best makespan: 1665
#
# interation: 104
# best makespan: 1665
#
# interation: 105
# best makespan: 1665
#
# interation: 106
# best makespan: 1665
#
# interation: 107
# best makespan: 1665
#
# interation: 108
# best makespan: 1665
#
# interation: 109
# best makespan: 1665
#
# interation: 110
# best makespan: 1665
#
# interation: 111
# best makespan: 1665
#
# interation: 112
# best makespan: 1665
#
# interation: 113
# best makespan: 1665
#
# interation: 114
# best makespan: 1665
#
# interation: 115
# best makespan: 1665
#
# interation: 116
# best makespan: 1665
#
# interation: 117
# best makespan: 1665
#
# interation: 118
# best makespan: 1665
#
# interation: 119
# best makespan: 1665
#
# interation: 120
# best makespan: 1665
#
# interation: 121
# best makespan: 1665
#
# interation: 122
# best makespan: 1665
#
# interation: 123
# best makespan: 1665
#
# interation: 124
# best makespan: 1665
#
# interation: 125
# best makespan: 1665
#
# interation: 126
# best makespan: 1665
#
# interation: 127
# best makespan: 1665
#
# interation: 128
# best makespan: 1665
#
# interation: 129
# best makespan: 1665
#
# interation: 130
# best makespan: 1665
#
# interation: 131
#
# interation: 293
# best makespan: 1590
#
# interation: 294
# best makespan: 1590
#
# interation: 295
# best makespan: 1590
#
# interation: 296
# best makespan: 1590
#
# interation: 297
# best makespan: 1590
#
# interation: 298
# best makespan: 1590
#
# interation: 299
# best makespan: 1590
#
# interation: 300
# best makespan: 1590
#
# interation: 301
# best makespan: 1590
#
# interation: 302
# best makespan: 1590
#
# interation: 303
# best makespan: 1590
#
# interation: 304
# best makespan: 1590
#
# interation: 305
# best makespan: 1590
#
# interation: 306
# best makespan: 1590
#
# interation: 307
# best makespan: 1590
#
# interation: 308
# best makespan: 1590
#
# interation: 309
# best makespan: 1590
#
# interation: 310
# best makespan: 1590
#
# interation: 311
# best makespan: 1590
#
# interation: 312
# best makespan: 1590
#
# interation: 313
# best makespan: 1590
#
# interation: 314
# best makespan: 1590
#
# interation: 315
# best makespan: 1590
#
# interation: 316
# best makespan: 1590
#
# interation: 317
# best makespan: 1590
#
# interation: 318
# best makespan: 1590
#
# interation: 319
# best makespan: 1590
#
# interation: 320
# best makespan: 1590
#
# interation: 321
# best makespan: 1590
#
# interation: 322
# best makespan: 1590
#
# interation: 323
# best makespan: 1590
#
# interation: 324
# best makespan: 1590
#
# interation: 325
# best makespan: 1590
#
# interation: 326
# best makespan: 1590
#
# interation: 327
# best makespan: 1590
#
# interation: 328
# best makespan: 1590
#
# interation: 329
# best makespan: 1590
#
# interation: 330
# best makespan: 1590
#
# interation: 331
# best makespan: 1590
#
# interation: 332
# best makespan: 1590
#
# interation: 333
# best makespan: 1590
#
# interation: 334
# best makespan: 1590
#
# interation: 335
# best makespan: 1590
#
# interation: 336
# best makespan: 1590
#
# interation: 337
# best makespan: 1590
#
# interation: 338
# best makespan: 1590
#
# interation: 339
# best makespan: 1590
#
# interation: 340
# best makespan: 1590
#
# interation: 341
# best makespan: 1590
#
# interation: 342
# best makespan: 1590
#
# interation: 343
# best makespan: 1590
#
# interation: 344
# best makespan: 1590
#
# interation: 345
# best makespan: 1590
#
# interation: 346
# best makespan: 1590
#
# interation: 347
# best makespan: 1590
#
# interation: 348
# best makespan: 1590
#
# interation: 349
# best makespan: 1590
#
# interation: 350
# best makespan: 1590
#
# interation: 351
# best makespan: 1590
#
# interation: 352
# best makespan: 1590
#
# interation: 353
# best makespan: 1590
#
# interation: 354
# best makespan: 1590
#
# interation: 355
# best makespan: 1590
#
# interation: 356
# best makespan: 1590
#
# interation: 357
# best makespan: 1590
#
# interation: 358
# best makespan: 1590
#
# interation: 359
# best makespan: 1590
#
# interation: 360
# best makespan: 1590
#
# interation: 361
# best makespan: 1590
#
# interation: 362
# best makespan: 1590
#
# interation: 363
# best makespan: 1590
#
# interation: 364
# best makespan: 1590
#
# interation: 365
# best makespan: 1590
#
# interation: 366
# best makespan: 1590
#
# interation: 367
# best makespan: 1590
#
# interation: 368
# best makespan: 1590
#
# interation: 369
# best makespan: 1590
#
# interation: 370
# best makespan: 1590
#
# interation: 371
# best makespan: 1590
#
# interation: 372
# best makespan: 1590
#
# interation: 373
# best makespan: 1590
#
# interation: 374
# best makespan: 1590
#
# interation: 375
# best makespan: 1590
#
# interation: 376
# best makespan: 1590
#
# interation: 377
# best makespan: 1590
#
# interation: 378
# best makespan: 1590
#
# interation: 379
# best makespan: 1590
#
# interation: 380
# best makespan: 1590
#
# interation: 381
# best makespan: 1590
#
# interation: 382
# best makespan: 1590
#
# interation: 383
# best makespan: 1590
#
# interation: 384
# best makespan: 1590
#
# interation: 385
# best makespan: 1590
#
# interation: 386
# best makespan: 1590
#
# interation: 387
# best makespan: 1590
#
# interation: 388
# best makespan: 1590
#
# interation: 389
# best makespan: 1590
#
# interation: 390
# best makespan: 1590
#
# interation: 391
# best makespan: 1590
#
# interation: 392
# best makespan: 1590
#
# interation: 393
# best makespan: 1590
#
# interation: 394
# best makespan: 1590
#
# interation: 395
# best makespan: 1590
#
# interation: 396
# best makespan: 1590
#
# interation: 397
# best makespan: 1590
#
# interation: 398
# best makespan: 1590
#
# interation: 399
# best makespan: 1590
#
# interation: 400
# best makespan: 1590
#
# interation: 401
# best makespan: 1590

# %%
import matplotlib.pyplot as plt

plt.plot(range(len(lineGraphDataList)), lineGraphDataList, label='makespan')
plt.xlabel('Period')
plt.ylabel('Value')
plt.title('Trend of Makespan')
plt.legend()
plt.grid(True)
plt.show()

# %%
def evaluateFitnessScore2(chromosome):
    
    # Job shows how many times of operation have been done
    # Job_end shows the time that last Ji ends
    # machine time shows the time that last job ends
    jobCounter = Counter()
    jobEndCounter = Counter()
    machineTimeCounter = Counter()
    
    for jobIteration in chromosome:
        jobNumber = jobIteration[0]
        machineNumber = jobIteration[1]
        
        # calculate the duration of that specific operation
        operationsDictList = data[jobNumber][jobCounter[jobNumber]]
        duration = [i["processTime"] for i in operationsDictList if i["machineNumber"] == machineNumber][0]
         
        # update the counter
        machineTimeCounter[machineNumber] = max(machineTimeCounter[machineNumber], jobEndCounter[jobNumber])
        machineTimeCounter[machineNumber] += duration
        jobEndCounter[jobNumber] = machineTimeCounter[machineNumber]
        jobCounter[jobNumber] += 1
        
    # calcualte makespan & tardiness
    makespan = jobEndCounter.most_common(1)[0][1]
    
    return makespan, jobEndCounter

# %%
print(elitismIndividualDF.iloc[0])
score, counter = evaluateFitnessScore2(elitismIndividualDF.iloc[0, 0])
print(counter)
counter.keys()
# Out:
# population    [[2, 3], [8, 7], [1, 5], [8, 7], [3, 2], [9, 8...
# makespan                                                   1590
# Name: 31, dtype: object
# Counter({np.int64(4): 1590, np.int64(9): 1539, np.int64(0): 1319, np.int64(2): 1303, np.int64(5): 1295, np.int64(3): 1180, np.int64(1): 1171, np.int64(7): 1141, np.int64(6): 1113, np.int64(8): 1006})
# dict_keys([np.int64(2), np.int64(8), np.int64(1), np.int64(3), np.int64(9), np.int64(6), np.int64(7), np.int64(5), np.int64(0), np.int64(4)])

# %%
demand = [{}]
# Out:
# [{np.int64(4): 1590,
#   np.int64(9): 1539,
#   np.int64(0): 1319,
#   np.int64(2): 1303,
#   np.int64(5): 1295,
#   np.int64(3): 1180,
#   np.int64(1): 1171,
#   np.int64(7): 1141,
#   np.int64(6): 1113,
#   np.int64(8): 1006}]
